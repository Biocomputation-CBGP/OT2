# %%
# First, we load the OpenTrons library and call home. 
import json
import opentrons.execute
protocol = opentrons.execute.get_protocol_api('2.11')
protocol.home()

# %%
# We define (inline) custom labware 
LABWARE_DEF_JSON_96_plate = """{"ordering":[["A1","B1","C1","D1","E1","F1","G1","H1"],["A2","B2","C2","D2","E2","F2","G2","H2"],["A3","B3","C3","D3","E3","F3","G3","H3"],["A4","B4","C4","D4","E4","F4","G4","H4"],["A5","B5","C5","D5","E5","F5","G5","H5"],["A6","B6","C6","D6","E6","F6","G6","H6"],["A7","B7","C7","D7","E7","F7","G7","H7"],["A8","B8","C8","D8","E8","F8","G8","H8"],["A9","B9","C9","D9","E9","F9","G9","H9"],["A10","B10","C10","D10","E10","F10","G10","H10"],["A11","B11","C11","D11","E11","F11","G11","H11"],["A12","B12","C12","D12","E12","F12","G12","H12"]],"brand":{"brand":"VWR Blueprint Depth 105","brandId":[]},"metadata":{"displayName":"VWR Blueprint Depth 105 96 Well Plate 390 µL","displayCategory":"wellPlate","displayVolumeUnits":"µL","tags":[]},"dimensions":{"xDimension":127.7,"yDimension":85.1,"zDimension":14.2},"wells":{"A1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":73.95,"z":3.7},"B1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":64.95,"z":3.7},"C1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":55.95,"z":3.7},"D1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":46.95,"z":3.7},"E1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":37.95,"z":3.7},"F1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":28.95,"z":3.7},"G1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":19.95,"z":3.7},"H1":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":14.31,"y":10.95,"z":3.7},"A2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":73.95,"z":3.7},"B2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":64.95,"z":3.7},"C2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":55.95,"z":3.7},"D2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":46.95,"z":3.7},"E2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":37.95,"z":3.7},"F2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":28.95,"z":3.7},"G2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":19.95,"z":3.7},"H2":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":23.31,"y":10.95,"z":3.7},"A3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":73.95,"z":3.7},"B3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":64.95,"z":3.7},"C3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":55.95,"z":3.7},"D3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":46.95,"z":3.7},"E3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":37.95,"z":3.7},"F3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":28.95,"z":3.7},"G3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":19.95,"z":3.7},"H3":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":32.31,"y":10.95,"z":3.7},"A4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":73.95,"z":3.7},"B4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":64.95,"z":3.7},"C4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":55.95,"z":3.7},"D4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":46.95,"z":3.7},"E4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":37.95,"z":3.7},"F4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":28.95,"z":3.7},"G4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":19.95,"z":3.7},"H4":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":41.31,"y":10.95,"z":3.7},"A5":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":50.31,"y":73.95,"z":3.7},"B5":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":50.31,"y":64.95,"z":3.7},"C5":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":50.31,"y":55.95,"z":3.7},"D5":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":50.31,"y":46.95,"z":3.7},"E5":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":50.31,"y":37.95,"z":3.7},"F5":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x
{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":113.31,"y":19.95,"z":3.7},"H12":{"depth":10.5,"totalLiquidVolume":390,"shape":"circular","diameter":6.42,"x":113.31,"y":10.95,"z":3.7}},"groups":[{"metadata":{"wellBottomShape":"flat"},"wells":["A1","B1","C1","D1","E1","F1","G1","H1","A2","B2","C2","D2","E2","F2","G2","H2","A3","B3","C3","D3","E3","F3","G3","H3","A4","B4","C4","D4","E4","F4","G4","H4","A5","B5","C5","D5","E5","F5","G5","H5","A6","B6","C6","D6","E6","F6","G6","H6","A7","B7","C7","D7","E7","F7","G7","H7","A8","B8","C8","D8","E8","F8","G8","H8","A9","B9","C9","D9","E9","F9","G9","H9","A10","B10","C10","D10","E10","F10","G10","H10","A11","B11","C11","D11","E11","F11","G11","H11","A12","B12","C12","D12","E12","F12","G12","H12"]}],"parameters":{"format":"irregular","quirks":[],"isTiprack":false,"isMagneticModuleCompatible":false,"loadName":"vwrblueprintdepth105_96_wellplate_390ul"},"namespace":"custom_beta","version":1,"schemaVersion":2,"cornerOffsetFromSlot":{"x":0,"y":0,"z":0}}"""
LABWARE_DEF_96_plate = json.loads(LABWARE_DEF_JSON_96_plate)

#ColdBlock
LABWARE_DEF_JSON_cold_block = LABWARE_DEF_JSON = """{"ordering":[["A1","B1","C1"],["A2","B2","C2"],["A3","B3","C3"],["A4","B4","C4"]],"brand":{"brand":"Cool_block","brandId":[]},"metadata":{"displayName":"Cool_block 12 Tube Rack with No 1.5 mL","displayCategory":"tubeRack","displayVolumeUnits":"µL","tags":[]},"dimensions":{"xDimension":127.5,"yDimension":85.5,"zDimension":70.3},"wells":{"A1":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":30.5,"y":63.5,"z":34.1},"B1":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":30.5,"y":42.5,"z":34.1},"C1":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":30.5,"y":21.5,"z":34.1},"A2":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":51.5,"y":63.5,"z":34.1},"B2":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":51.5,"y":42.5,"z":34.1},"C2":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":51.5,"y":21.5,"z":34.1},"A3":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":72.5,"y":63.5,"z":34.1},"B3":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":72.5,"y":42.5,"z":34.1},"C3":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":72.5,"y":21.5,"z":34.1},"A4":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":93.5,"y":63.5,"z":34.1},"B4":{"depth":36.2,"totalLiquidVolume":1500,"shape":"circular","diameter":8.8,"x":93.5,"y":42.5,"z":34.1},"C4":{"depth":36.2,"
{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":104.38,"y":20.24,"z":3.6},"H11":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":104.38,"y":11.24,"z":3.6},"A12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":74.24,"z":3.6},"B12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":65.24,"z":3.6},"C12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":56.24,"z":3.6},"D12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":47.24,"z":3.6},"E12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":38.24,"z":3.6},"F12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":29.24,"z":3.6},"G12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":20.24,"z":3.6},"H12":{"depth":20.9,"totalLiquidVolume":300,"shape":"circular","diameter":5.5,"x":113.38,"y":11.24,"z":3.6}},"groups":[{"metadata":{"wellBottomShape":"v"},"wells":["A1","B1","C1","D1","E1","F1","G1","H1","A2","B2","C2","D2","E2","F2","G2","H2","A3","B3","C3","D3","E3","F3","G3","H3","A4","B4","C4","D4","E4","F4","G4","H4","A5","B5","C5","D5","E5","F5","G5","H5","A6","B6","C6","D6","E6","F6","G6","H6","A7","B7","C7","D7","E7","F7","G7","H7","A8","B8","C8","D8","E8","F8","G8","H8","A9","B9","C9","D9","E9","F9","G9","H9","A10","B10","C10","D10","E10","F10","G10","H10","A11","B11","C11","D11","E11","F11","G11","H11","A12","B12","C12","D12","E12","F12","G12","H12"]}],"parameters":{"format":"irregular","quirks":[],"isTiprack":false,"isMagneticModuleCompatible":false,"loadName":"stacked_abgenes_pcr_96well_300ul"},"namespace":"custom_beta","version":1,"schemaVersion":2,"cornerOffsetFromSlot":{"x":0,"y":0,"z":0}}"""
LABWARE_DEF_pcr96 = json.loads(LABWARE_DEF_JSON_pcr96)

# %%
# Second, we load the labwares

# Tips
tips300 = protocol.load_labware(
    'opentrons_96_tiprack_300ul', 
    '10', 
    'Opentrons Tips 300ul')

tips20 = protocol.load_labware(
    'opentrons_96_tiprack_20ul', 
    '9', 
    'Opentrons Tips 20ul')
        
cells_source = protocol.load_labware_from_definition(LABWARE_DEF_96_plate, label = "Source 96", location="5")

source_coldblock = protocol.load_labware_from_definition(LABWARE_DEF_cold_block, label = "ColdBlock", location="11")

destination_plate = protocol.load_labware_from_definition(LABWARE_DEF_pcr96, label = "Destination 96 PCR", location="6")

# %%
# Load pippets 
pipette300 = protocol.load_instrument(
    "p300_single_gen2", 
    "right",
    tip_racks=[tips300])

pipette20 = protocol.load_instrument(
    "p20_single_gen2", 
    "left",
    tip_racks=[tips20])

# A function to automatically pick a suitable pippet for aVolume to transfer.
def give_me_optimal_pipette_to_use(aVolume):
    return pipette300 if aVolume > 20 else pipette20

# %%
##########################################
##    CHANGE ME      / inputs of script ##
##########################################

# Define total number of PCR reactions to perform
total_cell_samples_we_have_initially = 8
total_pcr_reactions_to_perform = total_cell_samples_we_have_initially * 3

# We define First well of destination plate that's gonna be used to place final pcr-reactions
destination_plate_starting_well_index = 0

# We define which is the starting well of the source plate (that holds liquid colonies) is
cells_source_plate_starting_well = 48

# Set starting tip (otherwise OT2 will assume tips are available from position A1)
pipette300.starting_tip = tips300.well('D9') # CHANGE to an available tip
pipette20.starting_tip = tips20.well('E5') # CHANGE to an available tip

# %%
# Define where reagents are located initially

pcr_reagent_milliq_location = source_coldblock['A1']
pcr_reagent_phire_mm_location = source_coldblock['A2']
pcr_reagent_dmso_location = source_coldblock['A3']

primer_A_location = source_coldblock['B1']
primer_B_location = source_coldblock['B2']
primer_C_location = source_coldblock['B3']
primer_D_location = source_coldblock['B4']

# %%
# Define composition of A SINGLE PCR reaction.

# 1ul primerONE [10uM]
# 1ul primerTWO [10uM]
# 2ul cell culture
# 10ul Phire MasterMix
# 6ul MilliQ
# 0.6ul DMSO

pcr_primer_ammount = 1
pcr_cell_ammount = 2
pcr_phire_mm_ammount = 10
pcr_milliQ_ammount = 6
pcr_dmso_ammount = 0.6

# %%
# Prepare GLOBAL MasterMix

# First we're gonna make a Global Mastermix which does NOT include primers.
# We need to know where to put TEMPORAL stuff (like the master mixes)

##### !!!!!!!! #####
# CHECK THAT MM TOTAL VOLUME IS LESS THAN THIS CONTAINER MAX VOLUME
##### !!!!!!!! #####

global_mastermix_location = source_coldblock['C1']

#I'm also defining location of
# FIX THIS! State actual location of temporal wells
primer_pair_A_mastermix_location = source_coldblock['C2']
primer_pair_B_mastermix_location = source_coldblock['C3']
primer_pair_C_mastermix_location = source_coldblock['C4']

# Lets compute how much of each PCR component we need for the Global Mastermix
extra_pipetting_volume_adjusting_factor = 1.20

global_mastermix_total_milliq_ammmount = total_pcr_reactions_to_perform \
                                        * pcr_milliQ_ammount \
                                        * extra_pipetting_volume_adjusting_factor

global_mastermix_total_phire_mm_ammmount = total_pcr_reactions_to_perform \
                                        * pcr_phire_mm_ammount \
                                        * extra_pipetting_volume_adjusting_factor

global_mastermix_total_dmso_ammmount = total_pcr_reactions_to_perform \
                                        * pcr_dmso_ammount \
                                        * extra_pipetting_volume_adjusting_factor

global_mastermix_total_volume = global_mastermix_total_milliq_ammmount + global_mastermix_total_phire_mm_ammmount + global_mastermix_total_dmso_ammmount

# %%
# Let's transfer liquids for the GlobalMM!
#MilliQ
aSuitablePippet = give_me_optimal_pipette_to_use(global_mastermix_total_milliq_ammmount)
aSuitablePippet.transfer(global_mastermix_total_milliq_ammmount, pcr_reagent_milliq_location, global_mastermix_location)

#Phire
aSuitablePippet = give_me_optimal_pipette_to_use(global_mastermix_total_phire_mm_ammmount)

# We change aspiration/dispensing speed to move liquid slower (for PCR kit mastermix / DMSO)
aSuitablePippet.flow_rate.aspirate = 10
aSuitablePippet.flow_rate.dispense = 10

aSuitablePippet.transfer(global_mastermix_total_phire_mm_ammmount, pcr_reagent_phire_mm_location, global_mastermix_location, new_tip = 'always')

# MIX?

#DMSO
aSuitablePippet = give_me_optimal_pipette_to_use(global_mastermix_total_dmso_ammmount)
aSuitablePippet.transfer(global_mastermix_total_dmso_ammmount, pcr_reagent_dmso_location, global_mastermix_location, new_tip = 'always')

# MIX?
# Global Master mix should be done at this point

# We RESTORE aspiration/dispensing speed to defaults
pipette300.flow_rate.aspirate = 92.86
pipette300.flow_rate.dispense = 92.86
pipette20.flow_rate.aspirate = 92.86
pipette20.flow_rate.dispense = 92.86


# ------

# %%
# We compute global mastermix total volume, and define the "mixing" volume will use for it.
# Then we mix
global_mastermix_mixing_volume = global_mastermix_total_volume / 3
aSuitablePippet = give_me_optimal_pipette_to_use(global_mastermix_mixing_volume)
aSuitablePippet.pick_up_tip()
aSuitablePippet.mix(5, global_mastermix_mixing_volume, global_mastermix_location)
aSuitablePippet.drop_tip()

# %%
# Now we split the GlobalMM into 3 subMasterMixes, each one will have a primer pair.

global_mastermix_total_volume = global_mastermix_total_dmso_ammmount \
                                + global_mastermix_total_phire_mm_ammmount \
                                + global_mastermix_total_milliq_ammmount

subMasterMixes_starting_volumes = global_mastermix_total_volume / 3
aSuitablePippet = give_me_optimal_pipette_to_use(subMasterMixes_starting_volumes)

# CHANGE: WE COULD RE-USE TIP TO DISTRIBUTE into subMastermixes
aSuitablePippet.pick_up_tip()
aSuitablePippet.transfer(subMasterMixes_starting_volumes, global_mastermix_location, primer_pair_A_mastermix_location, new_tip = 'never')
aSuitablePippet.transfer(subMasterMixes_starting_volumes, global_mastermix_location, primer_pair_B_mastermix_location, new_tip = 'never')
aSuitablePippet.transfer(subMasterMixes_starting_volumes, global_mastermix_location, primer_pair_C_mastermix_location, new_tip = 'never')
aSuitablePippet.drop_tip()

# And now we add each needed primer for each subMastermix.
# How much total primer do we need?
# Each primer pair will we used for a total of:
total_pcr_reaction_to_perform_by_primer_pair = total_pcr_reactions_to_perform / 3
sub_mastermix_total_primer_ammount = pcr_primer_ammount * total_pcr_reaction_to_perform_by_primer_pair

# %%
aSuitablePippet = give_me_optimal_pipette_to_use(sub_mastermix_total_primer_ammount)
subMM_mixing_volume = subMasterMixes_starting_volumes / 3
aSuitablePippet_for_mixing = give_me_optimal_pipette_to_use(subMM_mixing_volume)

# First primer pair
aSuitablePippet.transfer(sub_mastermix_total_primer_ammount, primer_A_location, primer_pair_A_mastermix_location)
aSuitablePippet.transfer(sub_mastermix_total_primer_ammount, primer_B_location, primer_pair_A_mastermix_location)
#MIX with Mixing pipet
aSuitablePippet_for_mixing.pick_up_tip()
aSuitablePippet_for_mixing.mix(3,subMM_mixing_volume,primer_pair_A_mastermix_location)
aSuitablePippet_for_mixing.drop_tip()

# Second Primer Pair
aSuitablePippet.transfer(sub_mastermix_total_primer_ammount, primer_B_location, primer_pair_B_mastermix_location)
aSuitablePippet.transfer(sub_mastermix_total_primer_ammount, primer_C_location, primer_pair_B_mastermix_location)
#MIX with Mixing pipet
aSuitablePippet_for_mixing.pick_up_tip()
aSuitablePippet_for_mixing.mix(3,subMM_mixing_volume,primer_pair_B_mastermix_location)
aSuitablePippet_for_mixing.drop_tip()

# Third primer pair
aSuitablePippet.transfer(sub_mastermix_total_primer_ammount, primer_C_location, primer_pair_C_mastermix_location)
aSuitablePippet.transfer(sub_mastermix_total_primer_ammount, primer_D_location, primer_pair_C_mastermix_location)
#MIX with Mixing pipet
aSuitablePippet_for_mixing.pick_up_tip()
aSuitablePippet_for_mixing.mix(3,subMM_mixing_volume,primer_pair_C_mastermix_location)
aSuitablePippet_for_mixing.drop_tip()

#BlowOUT?!

# At this point subMastermixes (containing primer pairs) should be done

# %%
#Now we distribute each subMastermix in the destination_plate
# Each single PCR reaction will use of subMasterMix a total ammount of:
single_pcr_submm_amount = pcr_primer_ammount + pcr_phire_mm_ammount + pcr_milliQ_ammount + pcr_dmso_ammount

#Manual dirty debug
# print(single_pcr_submm_amount)

# %%
#Let's use a pippet that can transfer such small volume
aSuitablePippet = give_me_optimal_pipette_to_use(single_pcr_submm_amount)

# Skip columns of destination well
################
# CUSTOMIZE THIS
################
# We define destinations for each primer pair subMastermix

primer_pair_A_mastermix_destination = destination_plate.wells()[0+destination_plate_starting_well_index:destination_plate_starting_well_index+total_cell_samples_we_have_initially]
primer_pair_B_mastermix_destination = destination_plate.wells()[destination_plate_starting_well_index+total_cell_samples_we_have_initially:destination_plate_starting_well_index+(2*total_cell_samples_we_have_initially)]
primer_pair_C_mastermix_destination = destination_plate.wells()[destination_plate_starting_well_index+(2*total_cell_samples_we_have_initially):destination_plate_starting_well_index+(3*total_cell_samples_we_have_initially)]

# First subMasterMix
# Remember will be preparing multiple columns of destination plate (total of 16 reactions)
aSuitablePippet.transfer(single_pcr_submm_amount, primer_pair_A_mastermix_location, primer_pair_A_mastermix_destination, new_tip=('once'))
aSuitablePippet.transfer(single_pcr_submm_amount, primer_pair_B_mastermix_location, primer_pair_B_mastermix_destination, new_tip=('once'))
aSuitablePippet.transfer(single_pcr_submm_amount, primer_pair_C_mastermix_location, primer_pair_C_mastermix_destination, new_tip=('once'))

# %%
# And now we distribute the cells
# remember we have a total of #total_cell_samples_we_have_initially# liquid cultures
aSuitablePippet = give_me_optimal_pipette_to_use(pcr_cell_ammount)

# And now lets distribute cells to the first PrimerPair
for i in range(0,total_cell_samples_we_have_initially):
    aSuitablePippet.transfer(pcr_cell_ammount, cells_source.wells()[cells_source_plate_starting_well+i], primer_pair_A_mastermix_destination[i], mix_after=(3, 4))

# And now lets distribute cells to the next PrimerPair
for i in range(0,total_cell_samples_we_have_initially):
    aSuitablePippet.transfer(pcr_cell_ammount, cells_source.wells()[cells_source_plate_starting_well+i], primer_pair_B_mastermix_destination[i], mix_after=(3, 4))

# And finally we transfer cells to the last PrimerPair
for i in range(0,total_cell_samples_we_have_initially):
    aSuitablePippet.transfer(pcr_cell_ammount, cells_source.wells()[cells_source_plate_starting_well+i], primer_pair_C_mastermix_destination[i], mix_after=(3, 4))
